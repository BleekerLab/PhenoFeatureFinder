# %%
import numpy as np

import sys
sys.path.append('../../src/phloemfinder/')

from metabolome_analysis import MetaboliteAnalysis

# %%
water_chemistry = MetaboliteAnalysis(
    metabolome_csv="../caddisfly/water_chemistry_long_random_correlated.csv",
    metabolome_feature_id_col="feature_id")

water_chemistry.validate_input_metabolome_df()

print("Number of total features before blank filtering = {0}".format(water_chemistry.metabolome.shape[0]))
# Out:
# Metabolome input data validated.
# Number of total features before blank filtering = 306

# %%
water_chemistry.create_density_plot()

# %%
water_chemistry.filter_out_unreliable_features(nb_times_detected=12)
print("numberof total features after unreliable feature filtering = {0}".format(water_chemistry.metabolome.shape[0]))
# Out:
# numberof total features after unreliable feature filtering = 303

# %%
water_chemistry.write_clean_metabolome_to_csv(path_of_cleaned_csv="../caddisfly/filetered_features_water_chemistry_long_random_correlated.csv")

# %%
water_chemistry.compute_pca_on_metabolites(n_principal_components=10)
water_chemistry.pca_performed
# Out:
# True

# %%
water_chemistry.create_scree_plot()

# %%
water_chemistry.metabolome_pca_reduced.shape
# Out:
# (60, 10)

# %%
water_chemistry.create_sample_score_plot(
    pc_x_axis=1,
    pc_y_axis=2,
    name_grouping_var='beek')

# %%
water_chemistry.plot_features_in_upset_plot()
